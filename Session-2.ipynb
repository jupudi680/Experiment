# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.DataFrame()
pd.to_csv=r"C:\Users\jupud_zwpuydo\OneDrive\Desktop\Operation K\GenAi\bank.csv"

# %%
bank_df=pd.read_csv (r"C:\Users\jupud_zwpuydo\OneDrive\Desktop\Operation K\GenAi\bank.csv",sep=';')
bank_df
# Out:
#       age            job  marital  education default  balance housing loan  \
# 0      30     unemployed  married    primary      no     1787      no   no
# 1      33       services  married  secondary      no     4789     yes  yes
# 2      35     management   single   tertiary      no     1350     yes   no
# 3      30     management  married   tertiary      no     1476     yes  yes
# 4      59    blue-collar  married  secondary      no        0     yes   no
# ...   ...            ...      ...        ...     ...      ...     ...  ...
# 4516   33       services  married  secondary      no     -333     yes   no
# 4517   57  self-employed  married   tertiary     yes    -3313     yes  yes
# 4518   57     technician  married  secondary      no      295      no   no
# 4519   28    blue-collar  married  secondary      no     1137      no   no
# 4520   44   entrepreneur   single   tertiary      no     1136     yes  yes
#
# ...

# %%
pd_to_csv=r"C:\Users\jupud_zwpuydo\OneDrive\Desktop\Operation K\GenAi\Visadataset.csv"

# %%
visa_df=pd.read_csv(r"C:\Users\jupud_zwpuydo\OneDrive\Desktop\Operation K\GenAi\Visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.shape
print('The number of rows are:{visa_df.shape[0]}')
print('The number of columns are:{visa_df.shape[0]}')
# Out:
# The number of rows are:{visa_df.shape[0]}
# The number of columns are:{visa_df.shape[0]}

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
visa_df.size
# Out:
# 305760

# %%
cols=visa_df.columns.tolist()
cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols.index('yr_of_estab')
# Out:
# 6

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %%
visa_df   #pandas
visa_df.values   #numpy arrays
# Out:
# array([['EZYV01', 'Asia', 'High School', ..., 'Hour', 'Y', 'Denied'],
#        ['EZYV02', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV03', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Denied'],
#        ...,
#        ['EZYV25478', 'Asia', "Master's", ..., 'Year', 'N', 'Certified'],
#        ['EZYV25479', 'Asia', "Master's", ..., 'Year', 'Y', 'Certified'],
#        ['EZYV25480', 'Asia', "Bachelor's", ..., 'Year', 'Y', 'Certified']],
#       shape=(25480, 12), dtype=object)

# %% [markdown]
# **loc-iloc**

# %%
#visa_df.iloc[rows,columns]
#visa_df.iloc[start:stop:end,start:stop:end]
visa_df.iloc[2:7,3:8]
#iloc will use full we can provide  direct columns names
#no need of indexs
# Out:
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
# 5                  Y                     N             2339         2012
# 6                  N                     N             4985         1994
#
#   region_of_employment
# 2                 West
# 3                 West
# 4                South
# 5                South
# 6                South

# %%
cols=['has_job_experience','requires_job_training']
visa_df.loc[250:6,cols]
# Out:
# Empty DataFrame
# Columns: [has_job_experience, requires_job_training]
# Index: []

# %%
visa_df.iloc[[100,200,300]]
visa_df.iloc[[100,200,300],:3]
visa_df.iloc[[100,200,300],[3,9]]
# Out:
#     has_job_experience unit_of_wage
# 100                  Y         Year
# 200                  Y         Year
# 300                  Y         Year

# %%
visa_df.iloc[[25000]]
# Out:
#          case_id      continent education_of_employee has_job_experience  \
# 25000  EZYV25001  South America              Master's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25000                     N             3204         1998
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25000                South          77003.2         Year                  Y
#
#       case_status
# 25000   Certified

# %%
#list [] numpy : 1D   pandas=series
#list [] numpy : 2D   pandas=dataframe
visa_df
visa_df['continent']
# Out:
# 0          Asia
# 1          Asia
# 2          Asia
# 3          Asia
# 4        Africa
#           ...
# 25475      Asia
# 25476      Asia
# 25477      Asia
# 25478      Asia
# 25479      Asia
# Name: continent, Length: 25480, dtype: object

# %%
visa_df['continent'].values
# Out:
# array(['Asia', 'Asia', 'Asia', ..., 'Asia', 'Asia', 'Asia'],
#       shape=(25480,), dtype=object)

# %% [markdown]
# **Dtypes**
# - Every series is a key value pair
# - every series is a dictionary
# - in dictinary if we want keys:.keys()
# - in dictinary if we want values:.values()

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %%
visa_df.keys()
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
pd.DataFrame(zip(keys,values),columns=['Name','Data type'])
# Out:
#                      Name Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %%
visa_df.dtypes.values
# Out:
# array([dtype('O'), dtype('O'), dtype('O'), dtype('O'), dtype('O'),
#        dtype('int64'), dtype('int64'), dtype('O'), dtype('float64'),
#        dtype('O'), dtype('O'), dtype('O')], dtype=object)

# %%
pd.DataFrame(visa_df.dtypes)
# Out:
#                              0
# case_id                 object
# continent               object
# education_of_employee   object
# has_job_experience      object
# requires_job_training   object
# no_of_employees          int64
# yr_of_estab              int64
# region_of_employment    object
# prevailing_wage        float64
# unit_of_wage            object
# full_time_position      object
# case_status             object

# %%
df=pd.DataFrame(visa_df.dtypes).reset_index()
df.columns=['Name','Data type']
df
# Out:
#                      Name Data type
# 0                 case_id    object
# 1               continent    object
# 2   education_of_employee    object
# 3      has_job_experience    object
# 4   requires_job_training    object
# 5         no_of_employees     int64
# 6             yr_of_estab     int64
# 7    region_of_employment    object
# 8         prevailing_wage   float64
# 9            unit_of_wage    object
# 10     full_time_position    object
# 11            case_status    object

# %% [markdown]
# **Task-2**

# %%
visa_df.dtypes
#Idea
#extract Keys and Values
#apply the for loop on values
#for i,j in zip(values)
#if i=='object':
# j

# %%
keys=visa_df.dtypes.keys().tolist()
values=visa_df.dtypes.values.tolist()
cat,num=[],[]
for i,j in zip(keys,values):
    if j=='object':
        cat.append(i)
    else:
        num.append(j)
print(cat,num)
# Out:
# ['case_id', 'continent', 'education_of_employee', 'has_job_experience', 'requires_job_training', 'region_of_employment', 'unit_of_wage', 'full_time_position', 'case_status'] [dtype('int64'), dtype('int64'), dtype('float64')]

# %% [markdown]
# **Select Dtypes**

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')
