# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
Names=['Rames','Suresh','Satish','Mahesh']
Age=[20,22,24,26]

# %% [markdown]
# **Step-1 :Create a Dataframe**

# %%
pd.DataFrame(Names)
pd.DataFrame(Names,'Names') #Names assume as index
pd.DataFrame(Names,columns='Names') # Columns Array
pd.DataFrame(Names,columns=['Names'])

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
pd.DataFrame(Names,'Names')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 3
#       1 Names=['Ramesh','Suresh','Satish','Mahesh']
#       2 Age=[20,22,24,26]
# ----> 3 pd.DataFrame(Names,'Names')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)    864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
# ...

# %%
pd.DataFrame(Names,columns='Names')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 pd.DataFrame(Names,columns='Names')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:867, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     859         mgr = arrays_to_mgr(
#     860             arrays,
#     861             columns,
#    (...)    864             typ=manager,
#     865         )
#     866     else:
# --> 867         mgr = ndarray_to_mgr(
#     868             data,
#     869             index,
#     870             columns,
#     871             dtype=dtype,
#     872             copy=copy,
#     873             typ=manager,
#     874         )
#     875 else:
#     876     mgr = dict_to_mgr(
#     877         {},
#     878         index,
#    (...)    881         typ=manager,
#     882     )
#
# ...

# %%
pd.DataFrame(Names,columns=['Names'])
# Out:
#     Names
# 0  Ramesh
# 1  Suresh
# 2  Satish
# 3  Mahesh

# %%
pd.DataFrame(Names,columns=['Names'])
pd.DataFrame(Names,
             index=['A','B','C','D'],
             columns=['Names'])
# Out:
#     Names
# A  Ramesh
# B  Suresh
# C  Satish
# D  Mahesh

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=[Names,Age]
pd.DataFrame(DATA).T
# Out:
#         0   1
# 0  Ramesh  20
# 1  Suresh  22
# 2  Satish  24
# 3  Mahesh  26

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
pd.DataFrame(DATA,index=['A','B','C','D'],columns=['Names','Age'])
# Out:
#     Names  Age
# A  Ramesh   20
# B  Suresh   22
# C  Satish   24
# D  Mahesh   26

# %% [markdown]
# **Step-2 : Add a new column to already existed dataframe**

# %%
df[cols_name]

# %%
Names=['Ramesh','Suresh','Satish','Mahesh']
Age=[20,22,24,26]
DATA=zip(Names,Age)
df=pd.DataFrame(DATA,columns=['Names','Age'])

# %%
df
# Out:
#     Names  Age
# 0  Ramesh   20
# 1  Suresh   22
# 2  Satish   24
# 3  Mahesh   26

# %%
df['Names']  #Selection
# Out:
# 0    Ramesh
# 1    Suresh
# 2    Satish
# 3    Mahesh
# Name: Names, dtype: object

# %%
df['Age']=[30,32,34,36] #Update

# %%
df
# Out:
#     Names  Age
# 0  Ramesh   30
# 1  Suresh   32
# 2  Satish   34
# 3  Mahesh   36

# %%
df['City']=['hyd','blr','pune','vja']  #Creation

# %%
df
# Out:
#     Names  Age  City
# 0  Ramesh   30   hyd
# 1  Suresh   32   blr
# 2  Satish   34  pune
# 3  Mahesh   36   vja

# %% [markdown]
# **step-4: Create a Dataframe using dictonary**

# %%
import pandas as pd
d={'Names':['Kiran','Teja','Mani','Satya','Vardhan'],
   'Age':[24,23,20,22,20],
   'City':['Vja','Hyd','Skm','Vzg','Gun']}
df=pd.DataFrame(d)
df
# Out:
#      Names  Age City
# 0    Kiran   24  Vja
# 1     Teja   23  Hyd
# 2     Mani   20  Skm
# 3    Satya   22  Vzg
# 4  Vardhan   20  Gun

# %%
d={'Names':'Kiran',
   'Age':'24',
   'City':'Vja'}
pd.DataFrame(d,index=[1])
# Out:
#    Names Age City
# 1  Kiran  24  Vja

# %% [markdown]
# **Step-5: Drop a new column**

# %%
 df.drop(labels,axis=0,index,columns,inplace=True)

# %%
df.drop('City')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 df.drop('City')
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# ...

# %%
df.drop('City',axis=1)
# Out:
#      Names  Age
# 0    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20

# %%
df.drop(columns=['City'])
# Out:
#      Names  Age
# 0    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20

# %%
df.drop(2)
# Out:
#      Names  Age City
# 0    Kiran   24  Vja
# 1     Teja   23  Hyd
# 3    Satya   22  Vzg
# 4  Vardhan   20  Gun

# %%
df.drop(2,axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df.drop(2,axis=1)
#
# File ~\AppData\Roaming\Python\Python313\site-packages\pandas\core\frame.py:5588, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5440 def drop(
#    5441     self,
#    5442     labels: IndexLabel | None = None,
#    (...)   5449     errors: IgnoreRaise = "raise",
#    5450 ) -> DataFrame | None:
#    5451     """
#    5452     Drop specified labels from rows or columns.
#    5453
#    (...)   5586             weight  1.0     0.8
#    5587     """
# -> 5588     return super().drop(
#    5589         labels=labels,
#    5590         axis=axis,
#    5591         index=index,
#    5592         columns=columns,
#    5593         level=level,
#    5594         inplace=inplace,
#    5595         errors=errors,
#    5596     )
#
# ...

# %%
df.drop(2,axis=0)
# Out:
#      Names  Age City
# 0    Kiran   24  Vja
# 1     Teja   23  Hyd
# 3    Satya   22  Vzg
# 4  Vardhan   20  Gun

# %%
df.drop(index=[2])
# Out:
#      Names  Age City
# 0    Kiran   24  Vja
# 1     Teja   23  Hyd
# 3    Satya   22  Vzg
# 4  Vardhan   20  Gun

# %%
df
# here the inplace=false because of the data cannot drop on column in table then we can use 
#inplace = True then the data will drop on column in table
# Out:
#      Names  Age City
# 0    Kiran   24  Vja
# 1     Teja   23  Hyd
# 2     Mani   20  Skm
# 3    Satya   22  Vzg
# 4  Vardhan   20  Gun

# %%
df.drop('City',axis=1,inplace=True)

# %%
df
# Out:
#      Names  Age
# 0    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20

# %% [markdown]
# **Step-6: Rename**

# %%
df.rename(index={0:8},inplace=True)
df
# Out:
#      Names  Age
# 8    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20

# %%
df
# Out:
#      Names  Age
# 8    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20

# %% [markdown]
# **step-7 Save the Dataframe**

# %% [markdown]
# - .csv
# - .xlsx
# - where you want to save : dictonary
# - on what name you want save : name of the file
# - on what extension you want to save : .csv ,,xlsx
# - different locations : "C:\Users\jupud_zwpuydo\FSDS\EDA\Pandas.ipynb"
# - "C:\Users\jupud_zwpuydo\FSDS\EDA\Pandas.ipynb\df1.xlsx"
# - "C:\Users\jupud_zwpuydo\FSDS\EDA\Pandas.ipynb\df1.csv"
# - same location no need to provide directory : 'df1.csv'

# %%
df.to_excel(r"C:\Users\jupud_zwpuydo\FSDS\EDA\df1.xlsx",index=False)
df.to_excel('df1.xlsx',index=False)

# %%
pd.read_excel(r"C:\Users\jupud_zwpuydo\FSDS\EDA\df1.xlsx")
# Out:
#      Names  Age
# 0    Kiran   24
# 1     Teja   23
# 2     Mani   20
# 3    Satya   22
# 4  Vardhan   20
